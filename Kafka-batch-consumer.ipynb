# %%
# Databricks notebook source
# MAGIC %md
# MAGIC ####Install below package in your cluster
# MAGIC org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.0

# COMMAND ----------

BOOTSTRAP_SERVER = "pkc-oxqxx9.us-east-1.aws.confluent.cloud:9092"
JAAS_MODULE = "kafkashaded.org.apache.kafka.common.security.plain.PlainLoginModule"
CLUSTER_API_KEY = "LY5LGMDSUZGLCXCI"
CLUSTER_API_SECRET = "cfltlyQNzeIHBL/YWU+uNVpV8zz3OKR5yC1/aM+EelcDEXPjbJ04qO/JPTgyucVQ"

# %%
df = ( spark.read
            .format("kafka")
            .option("kafka.bootstrap.servers", BOOTSTRAP_SERVER)
            .option("kafka.security.protocol", "SASL_SSL")
            .option("kafka.sasl.mechanism", "PLAIN")
            .option("kafka.sasl.jaas.config", f"{JAAS_MODULE} required username='{CLUSTER_API_KEY}' password='{CLUSTER_API_SECRET}';")
            .option("subscribe", "temperatures")
            .load()
        )

# %%
display(df)
